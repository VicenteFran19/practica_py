# %% [markdown]
# <a href="https://colab.research.google.com/github/VicenteFran19/practica_py/blob/main/analisis%20exp%20basico%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando librerias
import pandas as pd

# %%
# Importando datos
data = pd.read_excel('/content/EjerciciosS05.xlsx',sheet_name='EJ03')
data
# Out:
#       year  mileage  tax   mpg  engineSize  price
# 0     2016    24089  265  36.2         2.0  16000
# 1     2017    18615  145  36.2         2.0  15995
# 2     2015    27469  265  36.2         2.0  13998
# 3     2017    14736  150  36.2         2.0  18998
# 4     2017    36284  145  36.2         2.0  17498
# ...    ...      ...  ...   ...         ...    ...
# 6733  2011    30000   20  58.9         1.0   5500
# 6734  2011    36154  125  50.4         1.3   4985
# 6735  2012    46000  125  57.6         1.4   4995
# 6736  2011    60700  125  50.4         1.3   3995
# 6737  2011    45128  125  50.4         1.3   4495
#
# [6738 rows x 6 columns]

# %%
# Analisis descriptivo
data.describe()
# Out:
#               year        mileage          tax          mpg   engineSize  \
# count  6738.000000    6738.000000  6738.000000  6738.000000  6738.000000
# mean   2016.748145   22857.413921    94.697240    63.042223     1.471297
# std       2.204062   19125.464147    73.880776    15.836710     0.436159
# min    1998.000000       2.000000     0.000000     2.800000     0.000000
# 25%    2016.000000    9446.000000     0.000000    55.400000     1.000000
# 50%    2017.000000   18513.000000   135.000000    62.800000     1.500000
# 75%    2018.000000   31063.750000   145.000000    69.000000     1.800000
# max    2020.000000  174419.000000   565.000000   235.000000     4.500000
#
#               price
# count   6738.000000
# mean   12522.391066
# std     6345.017587
# min      850.000000
# 25%     8290.000000
# 50%    10795.000000
# 75%    14995.000000
# max    59995.000000

# %%
# Analisis de correlación
data.corr()
# Out:
#                 year   mileage       tax       mpg  engineSize     price
# year        1.000000 -0.727749  0.283455 -0.020607   -0.045567  0.420959
# mileage    -0.727749  1.000000 -0.205285  0.044889    0.182615 -0.297936
# tax         0.283455 -0.205285  1.000000 -0.430292    0.155727  0.214498
# mpg        -0.020607  0.044889 -0.430292  1.000000   -0.106868 -0.039910
# engineSize -0.045567  0.182615  0.155727 -0.106868    1.000000  0.727592
# price       0.420959 -0.297936  0.214498 -0.039910    0.727592  1.000000

# %%
# Analisis de Regresión

# %%
import statsmodels.api as sm
X = data.drop(columns=['price'])
Y = data['price']

# %%
# agregando la constante para tener el B0
X = sm.add_constant(X)

# %%
# Ejecutar modelo de regresion
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     4353.
# Date:                Sat, 30 Nov 2024   Prob (F-statistic):               0.00
# Time:                        03:05:34   Log-Likelihood:                -63693.
# No. Observations:                6738   AIC:                         1.274e+05
# Df Residuals:                    6732   BIC:                         1.274e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.688e+06   5.18e+04    -32.607      0.000   -1.79e+06   -1.59e+06
# ...

# %%
# Modelo v2 (eliminando 'mileage' por correlaciones)

X = data.drop(columns=['price','mileage'])
X = sm.add_constant(X)
Y = data['price']

model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     4758.
# Date:                Sat, 30 Nov 2024   Prob (F-statistic):               0.00
# Time:                        03:07:40   Log-Likelihood:                -64033.
# No. Observations:                6738   AIC:                         1.281e+05
# Df Residuals:                    6733   BIC:                         1.281e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.678e+06   3.81e+04    -70.276      0.000   -2.75e+06    -2.6e+06
# ...
